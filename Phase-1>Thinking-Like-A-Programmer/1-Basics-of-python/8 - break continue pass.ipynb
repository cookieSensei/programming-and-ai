# %% [markdown]
# # Break Continue Pass

# %%
counter = 10

while counter > 5:
    # IF the counter is 7, break out of the loop
    if counter == 7: break
    print(f"the value of counter: {counter}")
    counter -= 1 # Same as saying counter = counter - 1
# Out:
# the value of counter: 10
# the value of counter: 9
# the value of counter: 8

# %%
counter = 10

while counter > 5:
    counter -= 1 # Same as saying counter = counter - 1
    # IF the counter is 7, dont do anything for that value or loop
    # when ccounter is 7, skip to next loop
    if counter == 7: continue
    print(f"the value of counter: {counter}")
# Out:
# the value of counter: 9
# the value of counter: 8
# the value of counter: 6
# the value of counter: 5

# %%
for i in [1,2,7,9]:
    if i == 7: pass

# %%
def func1(array1):
    print(f"this is a custom function: {array1}")

# %%
func1(8)
# Out:
# this is a custom function: 8

# %%
func1(["high", "low"])
# Out:
# this is a custom function: ['high', 'low']

# %%
func2 = lambda vary: print(f"the value of vary is : {vary}")

func2(["a" , "b", "c"])
# Out:
# the value of vary is : ['a', 'b', 'c']

# %%
func3 = lambda x,y: x+y

func3(5,6)
# Out:
# 11

# %%
(lambda x,y: x+y)(7,8)
# Out:
# 15

# %%
def function_1(a,b):
    """"This function returns the summation of two numbers if the result is even. If result is odd we dont know what to do."""
    if (a+b)%2 == 0:
        return a+b
    else: pass
        #I havent' thought of the else block
        # so to avoid error i'll say to python
        # pass
        # meaning that i'll write my code here later on

# %%
function_1(2,9)

# %%
function_1(3,10)
